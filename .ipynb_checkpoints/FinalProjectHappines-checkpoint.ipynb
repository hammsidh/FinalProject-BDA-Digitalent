# %% [markdown]
# # Final Project Big Data Analytics
# Oleh Muhammad Sidhiq Setyawan

# %% [markdown]
# ## Introduction
# ------
# #### Tentang Kickstarter
#    Kickstarter adalah sebuah perusahaan *public-benefit* yang berbasis di Brooklyn, New York, Amerika. Misi perusahaan ini adalah untuk *"help bring creative projects to life"*. Kickstarter dilaporkan telah menerima lebih dari $ 1,9 miliar dalam bentuk komitmen dari 9,4 juta pendukung untuk mendanai 257.000 proyek kreatif, seperti film, musik, pertunjukan panggung, komik, jurnalisme, video game, teknologi dan proyek-proyek yang berkaitan dengan makanan.
#
#    Orang-orang yang mendukung proyek-proyek Kickstarter ditawari hadiah atau pengalaman nyata sebagai imbalan atas janji mereka. Model ini menelusuri akarnya hingga menjadi model langganan patronase seni, di mana para seniman akan pergi langsung ke audiens mereka untuk mendanai karya mereka.
#
# Proses crowdfunding sederhana:
# * Pemilik proyek mengusulkan proyek mereka dan memberikan informasi terkait seperti ide, harga, jadwal, dll.
# * Mendukung proyek yang tampaknya menarik
#
# Untuk memprediksi apakah proyek kickstarter akan berhasil atau akan gagal sebelum batas waktu yang sebenarnya. Juga mengidentifikasi faktor-faktor yang menentukan tingkat keberhasilan suatu proyek.

# %% [markdown]
# #### Fitur Dataset
# * ID:  internal kickstarter id
# * name:  Nama proyek
# * category:  category
# * main_category:  category kampanye
# * currency:  mata uang dari pendukung
# * deadline:  batas waktu untuk mengumpulkan dana(crowdfunding)
# * goal:  total dana yang dibutuhkan untuk menyelesaikan project
# * launched:  tanggal diluncurkan
# * pledged:  jumlah yang dijanjikan oleh pemberi dana
# * state:  Kondisi project saat ini
# * backers:  jumlah pendukung
# * country:  negara yang memberikan 'pledged'
# * usd pledged: jumlah 'Pledged' dalam USD (conversion made by KS)
# * usd_pledged_real: jumlah 'Pledged' dalam USD (conversion made by fixer.io api)
# * usd_goal_real: Jumlah 'Goal' dalam USD (conversion made by fixer.io api)

# %% [markdown]
# ## Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import feature_selection, linear_model
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import cluster, mixture 
from sklearn.preprocessing import StandardScaler
# import plotly.offline as py
# py.init_notebook_mode(connected=True)
# import plotly.graph_objs as go
# import plotly.tools as tls
# import plotly.express as px
from scipy import stats
from mlxtend.preprocessing import minmax_scaling
pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('Dataset/2017.csv')
df.head(72)
# Out:
#                     Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                    Norway               1            7.537      7.594445
# 1                   Denmark               2            7.522      7.581728
# 2                   Iceland               3            7.504      7.622030
# 3               Switzerland               4            7.494      7.561772
# 4                   Finland               5            7.469      7.527542
# 5               Netherlands               6            7.377      7.427426
# 6                    Canada               7            7.316      7.384403
# 7               New Zealand               8            7.314      7.379510
# 8                    Sweden               9            7.284      7.344095
# 9                 Australia              10            7.284      7.356651
# 10                   Israel              11            7.213      7.279853
# 11               Costa Rica              12            7.079      7.168112
# 12                  Austria              13            7.006      7.070670
# 13            United States              14            6.993      7.074657
# 14                  Ireland              15            6.977      7.043352
# 15                  Germany              16            6.951      7.005382
# 16                  Belgium              17            6.891      6.955821
# 17               Luxembourg              18            6.863      6.923686
# 18           United Kingdom              19            6.714      6.783792
# 19                    Chile              20            6.652      6.739251
# 20     United Arab Emirates              21            6.648      6.722047
# 21                   Brazil              22            6.635      6.725470
# 22           Czech Republic              23            6.609      6.683862
# 23                Argentina              24            6.599      6.690085
# 24                   Mexico              25            6.578      6.671149
# 25                Singapore              26            6.572      6.636723
# 26                    Malta              27            6.527      6.598397
# 27                  Uruguay              28            6.454      6.545906
# 28                Guatemala              29            6.454      6.566874
# 29                   Panama              30            6.452      6.557131
# ..                      ...             ...              ...           ...
# 42                Nicaragua              43            6.071      6.186584
# 43                  Ecuador              44            6.008      6.105848
# 44              El Salvador              45            6.003      6.108635
# 45                   Poland              46            5.973      6.053908
# 46               Uzbekistan              47            5.971      6.065538
# 47                    Italy              48            5.964      6.042737
# 48                   Russia              49            5.963      6.030275
# 49                   Belize              50            5.956      6.197242
# 50                    Japan              51            5.920      5.990719
# 51                Lithuania              52            5.902      5.982670
# 52                  Algeria              53            5.872      5.978286
# 53                   Latvia              54            5.850      5.920264
# 54              South Korea              55            5.838      5.922559
# 55                  Moldova              56            5.838      5.908371
# 56                  Romania              57            5.825      5.919694
# 57                  Bolivia              58            5.823      5.903977
# 58             Turkmenistan              59            5.822      5.885181
# 59               Kazakhstan              60            5.819      5.903642
# 60             North Cyprus              61            5.810      5.897366
# 61                 Slovenia              62            5.758      5.842225
# 62                     Peru              63            5.715      5.811947
# 63                Mauritius              64            5.629      5.729862
# 64                   Cyprus              65            5.621      5.714693
# 65                  Estonia              66            5.611      5.688140
# 66                  Belarus              67            5.569      5.646114
# 67                    Libya              68            5.525      5.676954
# 68                   Turkey              69            5.500      5.594865
# 69                 Paraguay              70            5.493      5.577381
# 70  Hong Kong S.A.R., China              71            5.472      5.549594
# 71              Philippines              72            5.430      5.545335
#
#     Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# 0      7.479556                  1.616463  1.533524                  0.796667
# 1      7.462272                  1.482383  1.551122                  0.792566
# 2      7.385970                  1.480633  1.610574                  0.833552
# 3      7.426227                  1.564980  1.516912                  0.858131
# 4      7.410458                  1.443572  1.540247                  0.809158
# 5      7.326574                  1.503945  1.428939                  0.810696
# 6      7.247597                  1.479204  1.481349                  0.834558
# 7      7.248490                  1.405706  1.548195                  0.816760
# 8      7.223905                  1.494387  1.478162                  0.830875
# 9      7.211349                  1.484415  1.510042                  0.843887
# 10     7.146146                  1.375382  1.376290                  0.838404
# 11     6.989888                  1.109706  1.416404                  0.759509
# 12     6.941330                  1.487097  1.459945                  0.815328
# 13     6.911343                  1.546259  1.419921                  0.774287
# 14     6.910649                  1.535707  1.558231                  0.809783
# 15     6.896619                  1.487923  1.472520                  0.798951
# 16     6.826179                  1.463781  1.462313                  0.818092
# 17     6.802314                  1.741944  1.457584                  0.845089
# 18     6.644209                  1.441634  1.496460                  0.805336
# 19     6.564749                  1.252785  1.284025                  0.819480
# 20     6.573952                  1.626343  1.266410                  0.726798
# 21     6.544531                  1.107353  1.431306                  0.616552
# 22     6.534138                  1.352682  1.433885                  0.754444
# 23     6.507915                  1.185295  1.440451                  0.695137
# 24     6.484851                  1.153184  1.210862                  0.709979
# 25     6.507277                  1.692278  1.353814                  0.949492
# 26     6.455603                  1.343280  1.488412                  0.821944
# 27     6.362094                  1.217560  1.412228                  0.719217
# 28     6.341126                  0.872002  1.255585                  0.540240
# 29     6.346870                  1.233748  1.373193                  0.706156
# ..          ...                       ...       ...                       ...
# 42     5.955417                  0.737299  1.287216                  0.653096
# 43     5.910152                  1.000820  1.286169                  0.685636
# 44     5.897364                  0.909784  1.182125                  0.596019
# 45     5.892092                  1.291788  1.445712                  0.699475
# 46     5.876463                  0.786441  1.548969                  0.498273
# 47     5.885264                  1.395067  1.444923                  0.853144
# 48     5.895725                  1.281778  1.469282                  0.547349
# 49     5.714757                  0.907975  1.081418                  0.450192
# 50     5.849281                  1.416915  1.436338                  0.913476
# 51     5.821330                  1.314582  1.473516                  0.628950
# 52     5.765714                  1.091864  1.146217                  0.617585
# 53     5.779736                  1.260749  1.404715                  0.638567
# 54     5.753441                  1.401678  1.128274                  0.900214
# 55     5.767629                  0.728871  1.251826                  0.589465
# 56     5.730305                  1.217684  1.150091                  0.685158
# 57     5.742023                  0.833757  1.227619                  0.473630
# 58     5.758819                  1.130777  1.493149                  0.437726
# 59     5.734358                  1.284556  1.384369                  0.606042
# 60     5.722633                  1.346911  1.186303                  0.834647
# 61     5.673775                  1.341206  1.452519                  0.790828
# 62     5.618054                  1.035225  1.218770                  0.630166
# 63     5.528138                  1.189396  1.209561                  0.638007
# 64     5.527307                  1.355938  1.131363                  0.844715
# 65     5.533860                  1.320879  1.476671                  0.695168
# 66     5.491885                  1.156558  1.444945                  0.637714
# 67     5.373046                  1.101803  1.357564                  0.520169
# 68     5.405135                  1.198274  1.337753                  0.637606
# 69     5.408619                  0.932537  1.507285                  0.579251
# 70     5.394406                  1.551675  1.262791                  0.943062
# 71     5.314665                  0.857699  1.253918                  0.468009
#
#      Freedom  Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0   0.635423    0.362012                       0.315964           2.277027
# 1   0.626007    0.355280                       0.400770           2.313707
# 2   0.627163    0.475540                       0.153527           2.322715
# 3   0.620071    0.290549                       0.367007           2.276716
# 4   0.617951    0.245483                       0.382612           2.430182
# 5   0.585384    0.470490                       0.282662           2.294804
# 6   0.611101    0.435540                       0.287372           2.187264
# 7   0.614062    0.500005                       0.382817           2.046456
# 8   0.612924    0.385399                       0.384399           2.097538
# 9   0.601607    0.477699                       0.301184           2.065211
# 10  0.405989    0.330083                       0.085242           2.801757
# 11  0.580132    0.214613                       0.100107           2.898639
# 12  0.567766    0.316472                       0.221060           2.138506
# 13  0.505741    0.392579                       0.135639           2.218113
# 14  0.573110    0.427858                       0.298388           1.773869
# 15  0.562511    0.336269                       0.276732           2.015770
# 16  0.539771    0.231503                       0.251343           2.124210
# 17  0.596628    0.283181                       0.318834           1.619512
# 18  0.508190    0.492774                       0.265428           1.704144
# 19  0.376895    0.326662                       0.082288           2.509586
# 20  0.608345    0.360942                       0.324490           1.734704
# 21  0.437454    0.162350                       0.111093           2.769267
# 22  0.490946    0.088107                       0.036873           2.451862
# 23  0.494519    0.109457                       0.059740           2.614005
# 24  0.412730    0.120990                       0.132774           2.837155
# 25  0.549841    0.345966                       0.464308           1.216362
# 26  0.588767    0.574731                       0.153066           1.556863
# 27  0.579392    0.175097                       0.178062           2.172410
# 28  0.531311    0.283488                       0.077223           2.893891
# 29  0.550027    0.210557                       0.070984           2.307200
# ..       ...         ...                            ...                ...
# 42  0.447552    0.301674                       0.130688           2.513931
# 43  0.455198    0.150112                       0.140135           2.290353
# 44  0.432453    0.078258                       0.089981           2.714594
# 45  0.520342    0.158466                       0.059308           1.797723
# 46  0.658249    0.415984                       0.246528           1.816914
# 47  0.256451    0.172790                       0.028028           1.813312
# 48  0.373783    0.052264                       0.032963           2.205607
# 49  0.547509    0.240016                       0.096581           2.631956
# 50  0.505626    0.120573                       0.163761           1.363224
# 51  0.234232    0.010165                       0.011866           2.228441
# 52  0.233336    0.069437                       0.146096           2.567604
# 53  0.325708    0.153075                       0.073843           1.993655
# 54  0.257922    0.206674                       0.063283           1.880378
# 55  0.240729    0.208779                       0.010091           2.807808
# 56  0.457004    0.133520                       0.004388           2.176831
# 57  0.558733    0.225561                       0.060478           2.443279
# 58  0.418272    0.249925                       0.259270           1.832910
# 59  0.437454    0.201964                       0.119283           1.784893
# 60  0.471204    0.266846                       0.155353           1.549158
# 61  0.572576    0.242649                       0.045129           1.313317
# 62  0.450003    0.126820                       0.047049           2.207269
# 63  0.491247    0.360934                       0.042182           1.697584
# 64  0.355112    0.271254                       0.041238           1.621249
# 65  0.479131    0.098891                       0.183249           1.357509
# 66  0.295400    0.155138                       0.156314           1.723233
# 67  0.465733    0.152074                       0.092610           1.835011
# 68  0.300741    0.046693                       0.099672           1.879278
# 69  0.473508    0.224151                       0.091066           1.685333
# 70  0.490969    0.374466                       0.293934           0.554633
# 71  0.585215    0.193513                       0.099332           1.972605
#
# [72 rows x 12 columns]

# %%
print('cek dimensi: \n',df.shape)
print('\ncek data NaN : \n',df.isnull().sum())
print('\ncek value setiap column: \n',df.nunique())
print(df.info())
print('\ndescribe dataframe: \n',df.describe())
# Out:
# cek dimensi:
#  (155, 12)
#
# cek data NaN :
#  Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64
#
# cek value setiap column:
#  Country                          155
# Happiness.Rank                   155
# Happiness.Score                  151
# Whisker.high                     155
# Whisker.low                      155
# Economy..GDP.per.Capita.         155
# Family                           155
# Health..Life.Expectancy.         155
# Freedom                          155
# Generosity                       155
# Trust..Government.Corruption.    155
# Dystopia.Residual                155
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
# Country                          155 non-null object
# Happiness.Rank                   155 non-null int64
# Happiness.Score                  155 non-null float64
# Whisker.high                     155 non-null float64
# Whisker.low                      155 non-null float64
# Economy..GDP.per.Capita.         155 non-null float64
# Family                           155 non-null float64
# Health..Life.Expectancy.         155 non-null float64
# Freedom                          155 non-null float64
# Generosity                       155 non-null float64
# Trust..Government.Corruption.    155 non-null float64
# Dystopia.Residual                155 non-null float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.6+ KB
# None
#
# describe dataframe:
#         Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# 25%                    0.663371    1.042635                  0.369866
# 50%                    1.064578    1.253918                  0.606042
# 75%                    1.318027    1.414316                  0.723008
# max                    1.870766    1.610574                  0.949492
#
#           Freedom  Generosity  Trust..Government.Corruption.  \
# count  155.000000  155.000000                     155.000000
# mean     0.408786    0.246883                       0.123120
# std      0.149997    0.134780                       0.101661
# min      0.000000    0.000000                       0.000000
# 25%      0.303677    0.154106                       0.057271
# 50%      0.437454    0.231538                       0.089848
# 75%      0.516561    0.323762                       0.153296
# max      0.658249    0.838075                       0.464308
#
#        Dystopia.Residual
# count         155.000000
# mean            1.850238
# std             0.500028
# min             0.377914
# 25%             1.591291
# 50%             1.832910
# 75%             2.144654
# max             3.117485

# %%
df.corr()
# Out:
#                                Happiness.Rank  Happiness.Score  Whisker.high  \
# Happiness.Rank                       1.000000        -0.992774     -0.993058
# Happiness.Score                     -0.992774         1.000000      0.999497
# Whisker.high                        -0.993058         0.999497      1.000000
# Whisker.low                         -0.991533         0.999520      0.998036
# Economy..GDP.per.Capita.            -0.813244         0.812469      0.811868
# Family                              -0.736753         0.752737      0.750934
# Health..Life.Expectancy.            -0.780716         0.781951      0.776634
# Freedom                             -0.551608         0.570137      0.569907
# Generosity                          -0.132620         0.155256      0.155462
# Trust..Government.Corruption.       -0.405842         0.429080      0.426459
# Dystopia.Residual                   -0.484506         0.475355      0.478824
#
#                                Whisker.low  Economy..GDP.per.Capita.  \
# Happiness.Rank                   -0.991533                 -0.813244
# Happiness.Score                   0.999520                  0.812469
# Whisker.high                      0.998036                  0.811868
# Whisker.low                       1.000000                  0.812267
# Economy..GDP.per.Capita.          0.812267                  1.000000
# Family                            0.753767                  0.688296
# Health..Life.Expectancy.          0.786385                  0.843077
# Freedom                           0.569808                  0.369873
# Generosity                        0.154904                 -0.019011
# Trust..Government.Corruption.     0.431223                  0.350944
# Dystopia.Residual                 0.471505                  0.024226
#
#                                  Family  Health..Life.Expectancy.   Freedom  \
# Happiness.Rank                -0.736753                 -0.780716 -0.551608
# Happiness.Score                0.752737                  0.781951  0.570137
# Whisker.high                   0.750934                  0.776634  0.569907
# Whisker.low                    0.753767                  0.786385  0.569808
# Economy..GDP.per.Capita.       0.688296                  0.843077  0.369873
# Family                         1.000000                  0.612080  0.424966
# Health..Life.Expectancy.       0.612080                  1.000000  0.349827
# Freedom                        0.424966                  0.349827  1.000000
# Generosity                     0.051693                  0.063191  0.316083
# Trust..Government.Corruption.  0.231841                  0.279752  0.499183
# Dystopia.Residual              0.070506                  0.054963  0.081926
#
#                                Generosity  Trust..Government.Corruption.  \
# Happiness.Rank                  -0.132620                      -0.405842
# Happiness.Score                  0.155256                       0.429080
# Whisker.high                     0.155462                       0.426459
# Whisker.low                      0.154904                       0.431223
# Economy..GDP.per.Capita.        -0.019011                       0.350944
# Family                           0.051693                       0.231841
# Health..Life.Expectancy.         0.063191                       0.279752
# Freedom                          0.316083                       0.499183
# Generosity                       1.000000                       0.294159
# Trust..Government.Corruption.    0.294159                       1.000000
# Dystopia.Residual               -0.116627                      -0.022755
#
#                                Dystopia.Residual
# Happiness.Rank                         -0.484506
# Happiness.Score                         0.475355
# Whisker.high                            0.478824
# Whisker.low                             0.471505
# Economy..GDP.per.Capita.                0.024226
# Family                                  0.070506
# Health..Life.Expectancy.                0.054963
# Freedom                                 0.081926
# Generosity                             -0.116627
# Trust..Government.Corruption.          -0.022755
# Dystopia.Residual                       1.000000

# %% [markdown]
# #### Memahami Variabel dalam Dataset
#
# Dataset memiliki 15 variabel termasuk ID. Karena ID adalah level dataset, kita dapat menetapkannya sebagai indeks data nanti. Variabel seperti nama, mata uang, tenggat waktu, tanggal diluncurkan dan negara sebagai penjelasan sendiri. Penjelasan dari beberapa variabel kunci adalah sebagai berikut:
#
# main_category: Ada 15 kategori utama untuk proyek ini. Kategori-kategori utama ini secara luas mengklasifikasikan proyek berdasarkan topik dan genre yang dimilikinya.
#
# category: Kategori Utama selanjutnya dibagi ke dalam beberapa kategori untuk memberikan gagasan proyek yang lebih umum. Misalnya, Kategori Utama "Teknologi" memiliki 15 kategori seperti Gadget, Web, Aplikasi, Perangkat Lunak, dll. Ada 159 kategori total.
#
# goal: Ini adalah jumlah sasaran yang harus dikumpulkan perusahaan untuk memulai proyeknya. Jumlah sasaran adalah variabel penting bagi perusahaan karena jika terlalu tinggi, proyek mungkin gagal mengumpulkan jumlah uang itu dan tidak berhasil. Jika terlalu rendah, maka mungkin akan mencapai tujuannya segera dan pendukung mungkin tidak tertarik untuk berjanji lebih.
#
# pledged: Ini adalah jumlah yang dikumpulkan oleh perusahaan melalui para pendukungnya. Di Kickstarter, jika jumlah total yang dijanjikan lebih rendah dari sasaran, maka proyek tidak berhasil dan perusahaan pemula tidak menerima dana apa pun. Jika jumlah yang dijanjikan lebih dari sasaran, perusahaan dianggap berhasil. Variabel "usd pledged" adalah jumlah uang yang diperoleh dalam dolar AS.
#
# backers: Ini adalah jumlah orang yang telah mendukung proyek dengan menjanjikan sejumlah uang.

# %%
## Menghapus kolom yang tidak terpakai/duplikat
df_train = df.drop(['Whisker.high','Whisker.low'], axis=1)
## Menambah kolom baru
# df_train['percent_funded'] =(df_train.usd_pledged_real / df_train.usd_goal_real)

# for value in df_train.percent_funded:
#     np.around(value, decimals=1)
    
df_train.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust..Government.Corruption.  Dystopia.Residual
# 0                       0.315964           2.277027
# 1                       0.400770           2.313707
# 2                       0.153527           2.322715
# 3                       0.367007           2.276716
# 4                       0.382612           2.430182

# %% [markdown]
# ### 1. Berdasarkan dataset yang dipilih, buatlah Scatter Plot untuk masing-masing features [Score: 15]
# #### 1.1

# %%
sns.pairplot(df_train)

# %%
df_train.corr()
# Out:
#                                Happiness.Rank  Happiness.Score  \
# Happiness.Rank                       1.000000        -0.992774
# Happiness.Score                     -0.992774         1.000000
# Economy..GDP.per.Capita.            -0.813244         0.812469
# Family                              -0.736753         0.752737
# Health..Life.Expectancy.            -0.780716         0.781951
# Freedom                             -0.551608         0.570137
# Generosity                          -0.132620         0.155256
# Trust..Government.Corruption.       -0.405842         0.429080
# Dystopia.Residual                   -0.484506         0.475355
#
#                                Economy..GDP.per.Capita.    Family  \
# Happiness.Rank                                -0.813244 -0.736753
# Happiness.Score                                0.812469  0.752737
# Economy..GDP.per.Capita.                       1.000000  0.688296
# Family                                         0.688296  1.000000
# Health..Life.Expectancy.                       0.843077  0.612080
# Freedom                                        0.369873  0.424966
# Generosity                                    -0.019011  0.051693
# Trust..Government.Corruption.                  0.350944  0.231841
# Dystopia.Residual                              0.024226  0.070506
#
#                                Health..Life.Expectancy.   Freedom  Generosity  \
# Happiness.Rank                                -0.780716 -0.551608   -0.132620
# Happiness.Score                                0.781951  0.570137    0.155256
# Economy..GDP.per.Capita.                       0.843077  0.369873   -0.019011
# Family                                         0.612080  0.424966    0.051693
# Health..Life.Expectancy.                       1.000000  0.349827    0.063191
# Freedom                                        0.349827  1.000000    0.316083
# Generosity                                     0.063191  0.316083    1.000000
# Trust..Government.Corruption.                  0.279752  0.499183    0.294159
# Dystopia.Residual                              0.054963  0.081926   -0.116627
#
#                                Trust..Government.Corruption.  \
# Happiness.Rank                                     -0.405842
# Happiness.Score                                     0.429080
# Economy..GDP.per.Capita.                            0.350944
# Family                                              0.231841
# Health..Life.Expectancy.                            0.279752
# Freedom                                             0.499183
# Generosity                                          0.294159
# Trust..Government.Corruption.                       1.000000
# Dystopia.Residual                                  -0.022755
#
#                                Dystopia.Residual
# Happiness.Rank                         -0.484506
# Happiness.Score                         0.475355
# Economy..GDP.per.Capita.                0.024226
# Family                                  0.070506
# Health..Life.Expectancy.                0.054963
# Freedom                                 0.081926
# Generosity                             -0.116627
# Trust..Government.Corruption.          -0.022755
# Dystopia.Residual                       1.000000

# %% [markdown]
# Berdasarkan pola data dari scatter plot (No. 1), pilih 2 features yang memiliki dugaan kuat ada korelasi. Narasikan alasannya! [Score: 10]

# %%
sns.heatmap(df_train.corr(), annot=True)

# %% [markdown]
# Setelah melihat heatmap diatas, yang memungkinkan untuk berkorelasi adalah warna cerah, karena semakin cerah akan mendekati 1, yang artinya sangat berkorelasi. Didapatkan nilai 0.843077 untuk korelasi 'Economy..GDP.per.Capita.' dengan 'Health..Life.Expectancy.'.

# %%
sns.lmplot('Economy..GDP.per.Capita.', 'Health..Life.Expectancy.', df_train)

# %% [markdown]
# Buatlah statistik deskriptif dari beberapa 2 features yang dipilih. Berikan narasi terhadap statistik tersebut [Score: 20]

# %%
df_train.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.      Family  \
# count      155.000000       155.000000                155.000000  155.000000
# mean        78.000000         5.354019                  0.984718    1.188898
# std         44.888751         1.131230                  0.420793    0.287263
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         39.500000         4.505500                  0.663371    1.042635
# 50%         78.000000         5.279000                  1.064578    1.253918
# 75%        116.500000         6.101500                  1.318027    1.414316
# max        155.000000         7.537000                  1.870766    1.610574
#
#        Health..Life.Expectancy.     Freedom  Generosity  \
# count                155.000000  155.000000  155.000000
# mean                   0.551341    0.408786    0.246883
# std                    0.237073    0.149997    0.134780
# min                    0.000000    0.000000    0.000000
# 25%                    0.369866    0.303677    0.154106
# 50%                    0.606042    0.437454    0.231538
# 75%                    0.723008    0.516561    0.323762
# max                    0.949492    0.658249    0.838075
#
#        Trust..Government.Corruption.  Dystopia.Residual
# count                     155.000000         155.000000
# mean                        0.123120           1.850238
# std                         0.101661           0.500028
# min                         0.000000           0.377914
# 25%                         0.057271           1.591291
# 50%                         0.089848           1.832910
# 75%                         0.153296           2.144654
# max                         0.464308           3.117485

# %% [markdown]
# Dari 2 features yang dipilih tersebut (No. 3), buatlah analisis model regresi (linear atau nonlinear). Jenis model regresi yang dipilih harus menyesuaikan pola sebaran data dari scatter plot. Model yang telah dibuat harus ditunjukkan secara visual dg grafik, serta tunjukkan tingkat keakuratannya (bisa menggunakan sembarang metrik) [Score: 25]

# %%
## Analisis Model Regresi
msk = np.random.rand(len(df_train)) < 0.8
train = df_train[msk]
test = df_train[~msk]

regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['Economy..GDP.per.Capita.']])
train_y = np.asanyarray(train[['Health..Life.Expectancy.']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.46451755]]
# Intercept:  [0.09307328]

# %%
## Regresi Linear
plt.scatter(train[['Economy..GDP.per.Capita.']], train[['Health..Life.Expectancy.']],  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Economy..GDP.per.Capita.")
plt.ylabel("Health..Life.Expectancy.")
# Out:
# Text(0, 0.5, 'Health..Life.Expectancy.')

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['Economy..GDP.per.Capita.']])
test_y = np.asanyarray(test[['Health..Life.Expectancy.']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
# Out:
# Mean absolute error: 0.11
# Residual sum of squares (MSE): 0.02
# R2-score: 0.55

# %% [markdown]
# Terhadap dataset yang diperoleh, lakukan pula analisis berikutnya (pilih salah satu): [Score: 30]

# %%
#Ignore Country and Happiness_Rank Columns

df_train = df_train.iloc[:,2:]

print("\n \n Dimenstion of dataset  : df_train.shape")
df_train.shape

df_train.dtypes

# Instantiate Scaler Object 
ss = StandardScaler()
# Fit and transform 
ss.fit_transform(df_train)
df_train.sample(20)
# Out:
#
#  Dimenstion of dataset  : df_train.shape
#      Happiness.Score  Economy..GDP.per.Capita.    Family  \
# 14             6.977                  1.535707  1.558231
# 6              7.316                  1.479204  1.481349
# 92             5.151                  0.022643  0.721151
# 45             5.973                  1.291788  1.445712
# 47             5.964                  1.395067  1.444923
# 65             5.611                  1.320879  1.476671
# 49             5.956                  0.907975  1.081418
# 29             6.452                  1.233748  1.373193
# 88             5.195                  1.315175  1.367043
# 149            3.495                  0.305445  0.431883
# 97             5.004                  0.596220  1.394239
# 18             6.714                  1.441634  1.496460
# 21             6.635                  1.107353  1.431306
# 79             5.269                  0.726884  0.672691
# 37             6.168                  1.361356  1.380229
# 63             5.629                  1.189396  1.209561
# 41             6.084                  1.291215  1.284646
# 42             6.071                  0.737299  1.287216
# 115            4.514                  0.636407  1.003187
# 38             6.105                  1.632952  1.259699
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 14                   0.809783  0.573110    0.427858
# 6                    0.834558  0.611101    0.435540
# 92                   0.113989  0.602127    0.291631
# 45                   0.699475  0.520342    0.158466
# 47                   0.853144  0.256451    0.172790
# 65                   0.695168  0.479131    0.098891
# 49                   0.450192  0.547509    0.240016
# 29                   0.706156  0.550027    0.210557
# 88                   0.795844  0.498465    0.095103
# 149                  0.247106  0.380426    0.196896
# 97                   0.553458  0.454943    0.428580
# 18                   0.805336  0.508190    0.492774
# 21                   0.616552  0.437454    0.162350
# 79                   0.402048  0.235215    0.315446
# 37                   0.519983  0.518631    0.325296
# 63                   0.638007  0.491247    0.360934
# 41                   0.618784  0.402265    0.416609
# 42                   0.653096  0.447552    0.301674
# 115                  0.257836  0.461603    0.249580
# 38                   0.632106  0.496338    0.228290
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 14                        0.298388           1.773869
# 6                         0.287372           2.187264
# 92                        0.282410           3.117485
# 45                        0.059308           1.797723
# 47                        0.028028           1.813312
# 65                        0.183249           1.357509
# 49                        0.096581           2.631956
# 29                        0.070984           2.307200
# 88                        0.015869           1.107683
# 149                       0.095665           1.837229
# 97                        0.039439           1.536723
# 18                        0.265428           1.704144
# 21                        0.111093           2.769267
# 79                        0.124348           2.792489
# 37                        0.008965           2.053247
# 63                        0.042182           1.697584
# 41                        0.065601           2.004449
# 42                        0.130688           2.513931
# 115                       0.078214           1.826705
# 38                        0.215160           1.640425

# %%
# Define CluserMethod class : which returns the clustering result based on input 

class ClusterMethodList(object) :
    def get_cluster_instance(self, argument,input_data,X):
        method_name = str(argument).lower()+ '_cluster'
        method = getattr(self,method_name,lambda : "Invalid Clustering method")
        return method(input_data,X)
    
    def kmeans_cluster(self,input_data,X):
        km = cluster.KMeans(n_clusters =input_data['n_clusters'] )
        return km.fit_predict(X)
   
    def meanshift_cluster(self,input_data,X):
        ms = cluster.MeanShift(bandwidth=input_data['bandwidth'])
        return  ms.fit_predict(X)
    
    def minibatchkmeans_cluster(self,input_data,X):
        two_means = cluster.MiniBatchKMeans(n_clusters=input_data['n_clusters'])
        return two_means.fit_predict(X)
   
    def dbscan_cluster(self,input_data,X):
        db = cluster.DBSCAN(eps=input_data['eps'])
        return db.fit_predict(X)
    
    def spectral_cluster(self,input_data,X):
        sp = cluster.SpectralClustering(n_clusters=input_data['n_clusters'])
        return sp.fit_predict(X)
   
    def affinitypropagation_cluster(self,input_data,X):
        affinity_propagation =  cluster.AffinityPropagation(damping=input_data['damping'], preference=input_data['preference'])
        affinity_propagation.fit(X)
        return affinity_propagation.predict(X)
       
    
    def birch_cluster(self,input_data,X):
        birch = cluster.Birch(n_clusters=input_data['n_clusters'])
        return birch.fit_predict(X)
   
    def gaussian_mixture_cluster(self,input_data,X):
        gmm = mixture.GaussianMixture( n_components=input_data['n_clusters'], covariance_type='full')
        gmm.fit(X)
        return  gmm.predict(X)

# %%
# Define Clustering Prcoess

def startClusteringProcess(list_cluster_method,input_data,no_columns,data_set):
    fig,ax = plt.subplots(no_rows,no_columns, figsize=(10,10)) 
    cluster_list = ClusterMethodList()
    i = 0
    j=0
    for cl in list_cluster_method :
        cluster_result = cluster_list.get_cluster_instance(cl,input_data,data_set)
        #convert cluster result array to DataFrame
        data_set[cl] = pd.DataFrame(cluster_result)
        ax[i,j].scatter(data_set.iloc[:, 4], data_set.iloc[:, 5],  c=cluster_result)
        ax[i,j].set_title(cl+" Cluster Result")
        j=j+1
        if( j % no_columns == 0) :
            j= 0
            i=i+1
    plt.subplots_adjust(bottom=-0.5, top=1.5)
    plt.show()

# %%
list_cluster_method = ['KMeans',"MeanShift","MiniBatchKmeans","DBScan","Spectral","AffinityPropagation","Birch","Gaussian_Mixture"]
# For Graph display 
no_columns = 2
no_rows = 4
# NOT all algorithms require this parameter
n_clusters= 3
bandwidth = 0.1 
# eps for DBSCAN
eps = 0.3
## Damping and perference for Affinity Propagation clustering method
damping = 0.9
preference = -200
input_data = {'n_clusters' :  n_clusters, 'eps' : eps,'bandwidth' : bandwidth, 'damping' : damping, 'preference' : preference}

# %%
startClusteringProcess(list_cluster_method,input_data,no_columns,df_train)
